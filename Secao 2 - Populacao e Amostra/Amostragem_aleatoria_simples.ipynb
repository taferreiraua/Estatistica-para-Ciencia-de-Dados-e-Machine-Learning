# %% [markdown]
# ***Packges***

# %%
import pandas as pd
import numpy as np
import random

# %% [markdown]
# ***Dados***

# %%
dataset = pd.read_csv('census.csv', on_bad_lines='skip')

# %%
dataset.shape
# Out:
# (24044, 15)

# %%
dataset.head()
# Out:
#    age          workclass  final-weight   education  education-num  \
# 0   39          State-gov       77516.0   Bachelors           13.0
# 1   50   Self-emp-not-inc       83311.0   Bachelors           13.0
# 2   38            Private      215646.0     HS-grad            9.0
# 3   53            Private      234721.0        11th            7.0
# 4   28            Private      338409.0   Bachelors           13.0
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loos  hour-per-week  native-country  income
# 0        2174.0           0.0           40.0   United-States   <=50K
# 1           0.0           0.0           13.0   United-States   <=50K
# 2           0.0           0.0           40.0   United-States   <=50K
# 3           0.0           0.0           40.0   United-States   <=50K
# 4           0.0           0.0           40.0            Cuba   <=50K

# %%
dataset.tail()
# Out:
#        age   workclass  final-weight      education  education-num  \
# 24039   30     Private      399522.0           11th            7.0
# 24040   60   State-gov      136939.0   Some-college           10.0
# 24041   56   Local-gov      264436.0   Some-college           10.0
# 24042   57     Private      199572.0           11th            7.0
# 24043   61         NaN           NaN            NaN            NaN
#
#                marital-status          occupation    relationship    race  \
# 24039   Married-spouse-absent   Handlers-cleaners       Unmarried   White
# 24040      Married-civ-spouse    Transport-moving         Husband   White
# 24041                Divorced     Exec-managerial   Not-in-family   White
# 24042      Married-civ-spouse   Machine-op-inspct         Husband   White
# 24043                     NaN                 NaN             NaN     NaN
#
#            sex  capital-gain  capital-loos  hour-per-week  native-country  \
# 24039   Female           0.0           0.0           40.0   United-States
# 24040     Male           0.0           0.0           40.0   United-States
# 24041   Female           0.0           0.0           40.0   United-States
# 24042     Male           0.0           0.0           40.0   United-States
# 24043      NaN           NaN           NaN            NaN             NaN
#
#        income
# 24039   <=50K
# 24040   <=50K
# 24041   <=50K
# 24042   <=50K
# 24043     NaN

# %% [markdown]
# ***Amostragem Aleatoria Simples***
#
#
# * *Escolhe-se um subconjunto menor de um conjunto maior aleatóriamente, com igual probabilidade.*

# %%
df_amostra_aleatoria_simples = dataset.sample(n=100, random_state=1)

# %%
df_amostra_aleatoria_simples.shape
# Out:
# (100, 15)

# %%
df_amostra_aleatoria_simples.head()
# Out:
#        age   workclass  final-weight      education  education-num  \
# 8271    45     Private      180309.0   Some-college           10.0
# 7576    40           ?      180362.0      Bachelors           13.0
# 9446    54     Private      139347.0        HS-grad            9.0
# 20686   51     Private      199688.0      Bachelors           13.0
# 20673   27   Local-gov      138917.0      Bachelors           13.0
#
#             marital-status          occupation    relationship    race  \
# 8271              Divorced   Machine-op-inspct       Unmarried   White
# 7576         Never-married                   ?       Own-child   White
# 9446               Widowed        Adm-clerical       Unmarried   White
# 20686   Married-civ-spouse     Exec-managerial         Husband   White
# 20673        Never-married      Prof-specialty   Not-in-family   White
#
#            sex  capital-gain  capital-loos  hour-per-week  native-country  \
# 8271    Female           0.0           0.0           40.0   United-States
# 7576    Female           0.0           0.0           40.0   United-States
# 9446    Female           0.0           0.0           40.0   United-States
# 20686     Male           0.0        1977.0           60.0               ?
# 20673     Male           0.0           0.0           35.0   United-States
#
#        income
# 8271    <=50K
# 7576    <=50K
# 9446    <=50K
# 20686    >50K
# 20673   <=50K

# %%
def amostragem_aleatoria_simples(dataset, amostras):
  return dataset.sample(n=amostras)

# %%
df_amostra_aleatoria_simples = amostragem_aleatoria_simples(dataset, 100)
df_amostra_aleatoria_simples.shape
df_amostra_aleatoria_simples.head()
# Out:
#        age workclass  final-weight      education  education-num  \
# 23900   62   Private      199193.0        HS-grad            9.0
# 3555    17         ?      213055.0           11th            7.0
# 8783    63         ?       83043.0      Bachelors           13.0
# 12738   39   Private      177154.0      Bachelors           13.0
# 7499    37   Private      176756.0   Some-college           10.0
#
#             marital-status          occupation    relationship    race  \
# 23900   Married-civ-spouse   Handlers-cleaners         Husband   White
# 3555         Never-married                   ?   Not-in-family   Other
# 8783    Married-civ-spouse                   ?         Husband   White
# 12738   Married-civ-spouse               Sales         Husband   White
# 7499    Married-civ-spouse        Adm-clerical         Husband   Black
#
#            sex  capital-gain  capital-loos  hour-per-week  native-country  \
# 23900     Male           0.0           0.0           25.0   United-States
# 3555    Female           0.0           0.0           20.0   United-States
# 8783      Male           0.0        2179.0           45.0   United-States
# 12738     Male       15024.0           0.0           50.0   United-States
# 7499      Male           0.0        1485.0           70.0   United-States
#
#        income
# 23900   <=50K
# 3555    <=50K
# 8783    <=50K
# 12738    >50K
# 7499     >50K
